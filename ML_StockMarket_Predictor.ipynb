# %% [markdown]
# <a href="https://colab.research.google.com/github/ryannnchang/StockPredictor/blob/main/ML_StockMarket_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ML Stock Market Prediction (Classification and Regression)
# Making a Stock Market Predictor using ML
#
# Goal 1: Predict ONE stock prices
# Goal 2: Predict multiple stock prices
#
#
# Steps:
# 1. Data Collection
# 2. Data Processing and Feature Selection
# 3. Choose ML model (SVM, random forest, KNN)
# 4. Evaluate results by simulating a trading session and calculate returns

# %% [markdown]
# ## Dataset Import

# %%
import yfinance as yf
import pandas as pd
import numpy as np

dat = yf.Ticker('GOOG')
df = dat.history(period='5y')
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-07-27 00:00:00-04:00  75.332210  76.593215  75.312824  76.057899
# 2020-07-28 00:00:00-04:00  75.808380  75.872991  74.440512  74.573715
# 2020-07-29 00:00:00-04:00  74.870964  76.110195  74.622934  75.651321
# 2020-07-30 00:00:00-04:00  74.407708  76.439136  74.170122  76.120033
# 2020-07-31 00:00:00-04:00  74.805840  75.001675  72.271899  73.709854
#
#                              Volume  Dividends  Stock Splits
# Date
# 2020-07-27 00:00:00-04:00  24920000        0.0           0.0
# 2020-07-28 00:00:00-04:00  34044000        0.0           0.0
# 2020-07-29 00:00:00-04:00  22130000        0.0           0.0
# 2020-07-30 00:00:00-04:00  33428000        0.0           0.0
# 2020-07-31 00:00:00-04:00  68798000        0.0           0.0
